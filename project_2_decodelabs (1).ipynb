# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
df=pd.read_csv("dataset_p2.csv")

# %%
#first 5 rows 
df.head()
# Out:
#      OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000  2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001  2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002  2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003  2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004  2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
#last 5 rows
df.tail()
# Out:
#         OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 1195  ORD201195  2024-06-20     C21126     Desk         1     107.04
# 1196  ORD201196  2024-03-04     C20095  Monitor         2     662.53
# 1197  ORD201197  2023-07-13     C79674   Tablet         2     436.84
# 1198  ORD201198  2024-08-22     C64753    Chair         4     262.52
# 1199  ORD201199  2023-06-11     C57502   Tablet         4     560.58
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 1195     392 Main St   Credit Card   Cancelled    TRK38009181            6
# 1196     778 Main St        Online   Cancelled    TRK69207593            5
# 1197     275 Main St        Online   Delivered    TRK88039356            2
# 1198     509 Main St    Debit Card   Cancelled    TRK71683331            4
# 1199     201 Main St     Gift Card    Returned    TRK51116746            6
#
#      CouponCode ReferralSource  TotalPrice
# 1195   FREESHIP         Google      107.04
# ...

# %%
#shape of dataset means number of rows and columns 
df.shape
# Out:
# (1200, 14)

# %%
#columns 
df.columns
# Out:
# Index(['OrderID', 'Date', 'CustomerID', 'Product', 'Quantity', 'UnitPrice',
#        'ShippingAddress', 'PaymentMethod', 'OrderStatus', 'TrackingNumber',
#        'ItemsInCart', 'CouponCode', 'ReferralSource', 'TotalPrice'],
#       dtype='object')

# %%
#datatypes
df.dtypes
# Out:
# OrderID             object
# Date                object
# CustomerID          object
# Product             object
# Quantity             int64
# UnitPrice          float64
# ShippingAddress     object
# PaymentMethod       object
# OrderStatus         object
# TrackingNumber      object
# ItemsInCart          int64
# CouponCode          object
# ReferralSource      object
# TotalPrice         float64
# dtype: object

# %%
#information of dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   object
#  1   Date             1200 non-null   object
#  2   CustomerID       1200 non-null   object
#  3   Product          1200 non-null   object
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   object
#  7   PaymentMethod    1200 non-null   object
#  8   OrderStatus      1200 non-null   object
#  9   TrackingNumber   1200 non-null   object
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    object
#  12  ReferralSource   1200 non-null   object
#  13  TotalPrice       1200 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 131.4+ KB

# %%
#check null values
df.isnull()
# Out:
#       OrderID   Date  CustomerID  Product  Quantity  UnitPrice  \
# 0       False  False       False    False     False      False
# 1       False  False       False    False     False      False
# 2       False  False       False    False     False      False
# 3       False  False       False    False     False      False
# 4       False  False       False    False     False      False
# ...       ...    ...         ...      ...       ...        ...
# 1195    False  False       False    False     False      False
# 1196    False  False       False    False     False      False
# 1197    False  False       False    False     False      False
# 1198    False  False       False    False     False      False
# 1199    False  False       False    False     False      False
#
#       ShippingAddress  PaymentMethod  OrderStatus  TrackingNumber  \
# 0               False          False        False           False
# 1               False          False        False           False
# ...

# %%
#total number of null values
df.isnull().sum()
# Out:
# OrderID              0
# Date                 0
# CustomerID           0
# Product              0
# Quantity             0
# UnitPrice            0
# ShippingAddress      0
# PaymentMethod        0
# OrderStatus          0
# TrackingNumber       0
# ItemsInCart          0
# CouponCode         309
# ReferralSource       0
# TotalPrice           0
# dtype: int64

# %%
#check duplicate rows 
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# Length: 1200, dtype: bool

# %%
#drop duplicates
df.drop_duplicates(inplace=True)

# %%
#it gives count,means,std,min,max.....
df.describe()
# Out:
#           Quantity    UnitPrice  ItemsInCart   TotalPrice
# count  1200.000000  1200.000000  1200.000000  1200.000000
# mean      2.945833   356.412750     5.485000  1053.968300
# std       1.407557   197.177146     2.281983   819.856558
# min       1.000000    11.390000     1.000000    11.390000
# 25%       2.000000   186.062500     4.000000   410.520000
# 50%       3.000000   364.210000     5.000000   823.615000
# 75%       4.000000   521.570000     7.000000  1578.475000
# max       5.000000   699.930000    10.000000  3456.400000

# %%
df["TotalPrice"].mean()
# Out:
# 1053.9683

# %%
df["TotalPrice"].median()
# Out:
# 823.615

# %%
df["TotalPrice"].mode()
# Out:
# 0     211.14
# 1     367.34
# 2     410.52
# 3     635.90
# 4    2517.36
# Name: TotalPrice, dtype: float64

# %%
df["Product"].mode()
# Out:
# 0    Printer
# Name: Product, dtype: object

# %%
df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Online         258
# Cash           246
# Credit Card    234
# Debit Card     232
# Gift Card      230
# Name: count, dtype: int64

# %%
df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Online         258
# Cash           246
# Credit Card    234
# Debit Card     232
# Gift Card      230
# Name: count, dtype: int64

# %%
df["Quantity"].value_counts()
# Out:
# Quantity
# 1    255
# 4    251
# 2    240
# 3    237
# 5    217
# Name: count, dtype: int64

# %%
df["UnitPrice"].value_counts()
# Out:
# UnitPrice
# 183.67    2
# 127.18    2
# 629.34    2
# 228.91    2
# 133.39    2
#          ..
# 423.93    1
# 53.93     1
# 427.06    1
# 287.13    1
# 560.58    1
# Name: count, Length: 1193, dtype: int64

# %%
df["ReferralSource"].value_counts()
# Out:
# ReferralSource
# Instagram    259
# Email        250
# Google       241
# Facebook     228
# Referral     222
# Name: count, dtype: int64

# %%
df["Quantity"].median()
# Out:
# 3.0

# %%
df["TotalPrice"].median()
# Out:
# 823.615

# %%
df["Product"].value_counts()
# Out:
# Product
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64

# %%
df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Online         258
# Cash           246
# Credit Card    234
# Debit Card     232
# Gift Card      230
# Name: count, dtype: int64

# %%
df["OrderStatus"].value_counts()
# Out:
# OrderStatus
# Cancelled    250
# Returned     247
# Pending      237
# Shipped      235
# Delivered    231
# Name: count, dtype: int64

# %%
df["TotalPrice"].sum()
# Out:
# 1264761.96

# %%
#Highest Order
df["TotalPrice"].max()
# Out:
# 3456.4

# %%
#lowest order
df["TotalPrice"].min()
# Out:
# 11.39

# %%
#Most Expensive Product
df.sort_values("UnitPrice", ascending=False).head()
# Out:
#         OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 742   ORD200742  2024-11-30     C41974   Laptop         3     699.93
# 1002  ORD201002  2025-06-19     C83911   Tablet         4     699.88
# 908   ORD200908  2025-05-06     C35117     Desk         2     697.93
# 389   ORD200389  2023-12-17     C29703     Desk         4     697.50
# 1170  ORD201170  2023-08-03     C94257  Printer         2     697.19
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 742      726 Main St          Cash    Returned    TRK48051468            7
# 1002     944 Main St          Cash     Pending    TRK33188106            5
# 908      332 Main St   Credit Card   Cancelled    TRK27155709            2
# 389      558 Main St          Cash     Shipped    TRK40543461            7
# 1170     762 Main St          Cash    Returned    TRK40220743            7
#
#      CouponCode ReferralSource  TotalPrice
# 742      SAVE10         Google     2099.79
# ...

# %%
#Cheapest Product
df.sort_values("UnitPrice").head()
# Out:
#         OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 1161  ORD201161  2023-10-16     C32570    Phone         1      11.39
# 67    ORD200067  2024-12-09     C25587  Printer         4      12.10
# 863   ORD200863  2024-05-20     C98276    Phone         1      14.06
# 251   ORD200251  2025-05-15     C93175  Monitor         4      14.69
# 473   ORD200473  2025-02-25     C28552    Chair         2      14.93
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 1161     826 Main St          Cash   Cancelled    TRK35969968            6
# 67       440 Main St    Debit Card   Cancelled    TRK55105323            8
# 863      471 Main St   Credit Card     Pending    TRK74207282            5
# 251      814 Main St          Cash   Cancelled    TRK32995144            9
# 473      449 Main St        Online     Shipped    TRK71597160            4
#
#      CouponCode ReferralSource  TotalPrice
# 1161   WINTER15          Email       11.39
# ...

# %%
#Product-wise Sales
df.groupby("Product")["TotalPrice"].sum()
# Out:
# Product
# Chair      195620.11
# Desk       167459.93
# Laptop     192126.56
# Monitor    175651.41
# Phone      151722.39
# Printer    195612.61
# Tablet     186568.95
# Name: TotalPrice, dtype: float64

# %%
#Average Quantity Sold
df.groupby("Product")["Quantity"].mean()
# Out:
# Product
# Chair      3.157303
# Desk       2.988235
# Laptop     3.092486
# Monitor    2.944785
# Phone      2.634615
# Printer    2.994475
# Tablet     2.776536
# Name: Quantity, dtype: float64

# %%
#VISUALIZATIONS

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Product",data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="PaymentMethod", data=df)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="OrderStatus", data=df)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["TotalPrice"], bins=20)
plt.xlabel("Total Price")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(x=df["TotalPrice"])
plt.show()

# %%
#Correlation
corr = df.corr(numeric_only=True)
sns.heatmap(corr,
            annot=True,
            cmap="coolwarm")
plt.show()

# %%
#CONCLUSION
'''Dataset contains 1200 rows and 14 columns.
No duplicate records were found.
309 missing values exist in the CouponCode column.
Average order value is 1053.97.
Median order value is 823.62.
Printer is the most frequently ordered product.
Chair generated the highest total sales revenue.
Online is the most commonly used payment method.
Cancelled orders are slightly more common than other order statuses.
The dataset shows a wide range of order values, indicating different customer spending patterns.'''
